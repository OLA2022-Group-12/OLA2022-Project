# %%
import numpy as np
import json
import io

from pprint import pprint as pp

import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.colors import BASE_COLORS
from matplotlib.gridspec import GridSpec
import graphviz
from PIL import Image

# %%
from ola2022_project.environment import (
    alpha_function,
    EnvironmentData,
    UserClassParameters,
    get_day_of_interactions,
    Feature,
    example_environment,
    show_alpha_ratios,
    show_class_ratios,
    show_product_graph,
)
from ola2022_project.utils import add_headers_to_plot

# %%
example_env = example_environment()

# %%
env = example_env
pp(env)
# Out:
# EnvironmentData(total_budget=300,
#                 class_ratios=[0.3, 0.6, 0.1],
#                 class_features=[[[Feature(name='feature_1', value=0),
#                                   Feature(name='feature_2', value=0)],
#                                  [Feature(name='feature_1', value=0),
#                                   Feature(name='feature_2', value=1)]],
#                                 [[Feature(name='feature_1', value=1),
#                                   Feature(name='feature_2', value=0)]],
#                                 [[Feature(name='feature_1', value=1),
#                                   Feature(name='feature_2', value=1)]]],
#                 product_prices=[3, 15, 8, 22, 1],
#                 classes_parameters=[[UserClassParameters(reservation_price=10, upper_bound=0.2, max_useful_budget=120),
#                                      UserClassParameters(reservation_price=10, upper_bound=0.15, max_useful_budget=120),
# ...

# %%
fig = plt.figure()
show_class_ratios(env, fig.gca())

fig = plt.figure(figsize=(8, 3))
show_alpha_ratios(env, fig)

fig = plt.figure()
show_product_graph(env, fig.gca())

plt.show()
